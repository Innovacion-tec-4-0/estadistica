# %% [markdown]
# #Proyecto final de cursada Estadística + IOT

# %% [markdown]
# ##*Integrantes:*
#
# ###*   Ferreyra Santiago
# ###*   Cesar Martins
# ###*   Gaston Trejo
# ###*   M. Victoria Urcola
#
#
# Este dataset examina diversas ciudades en términos de su desarrollo como "ciudades inteligentes", considerando aspectos como movilidad, medio ambiente, gobierno, economía, personas y vida inteligente.
#
# "...Se utilizaron diferentes tipos de sensores de IoT (Internet de las cosas) para recopilar y gestionar datos, combinada con muchas otras integraciones técnicas en los centros de nuestras ciudades, definiendo el futuro de la integración de los datos y la automatización en nuestra vida urbana. Piensese en las Smart Cities como una experiencia para el cliente, para los residentes de una ciudad.
#
# El equipo de Leap Data utilizó índices reconocidos mundialmente (formalizados para la evaluación de iniciativas de ciudades inteligentes) y desarrolló un modelo de datos para interpretar la posición de Calgary y Edmonton en relación con los líderes globales de las actividades de ciudades inteligentes. Los índices utilizados para crear estos conocimientos se desarrollaron exclusivamente a partir de conjuntos de datos abiertos...", fuente  : 'https://www.kaggle.com/datasets/magdamonteiro/smart-cities-index-datasets' ,

# %% [markdown]
# #Desarrollo

# %%
# @title importamos pandas
import pandas as pd
import io
import os

import matplotlib.pyplot as plt

# %%
# @title cargamos DS por upload
'''
from google.colab import files
csvsubido = files.upload()

df = pd.read_csv(io.BytesIO(csvsubido['Smart_City_index_headers.csv']))
'''
# Out:
# "\nfrom google.colab import files\ncsvsubido = files.upload()\n\ndf = pd.read_csv(io.BytesIO(csvsubido['Smart_City_index_headers.csv']))\n"

# %%
# @title cargamos DS montando drive
from google.colab import drive
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Grupo ISPC Innov/2024/Estadistica/IoT.csv/Smart_City_index_headers.csv'

df = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##Hacemos una exploración de nuestro DataSet

# %%
# @title Visualizamos cuántas filas y columnas trae el DS
df.shape
# Out:
# (102, 11)

# %%
# @title Traemos los nombres de las columnas
df.columns
# Out:
# Index(['Id', 'City', 'Country', 'Smart_Mobility ', 'Smart_Environment',
#        'Smart_Government ', 'Smart_Economy ', 'Smart_People', 'Smart_Living',
#        'SmartCity_Index', 'SmartCity_Index_relative_Edmonton'],
#       dtype='object')

# %%
df.City
# Out:
# 0               Oslo
# 1             Bergen
# 2          Amsterdam
# 3         Copenhagen
# 4          Stockholm
#            ...
# 97              Riga
# 98           Beijing
# 99     St Petersburg
# 100          Calgary
# 101         Edmonton
# Name: City, Length: 102, dtype: object

# %%
# @title Consultamos el DS
df.head(102)
# Out:
#       Id           City      Country  Smart_Mobility   Smart_Environment  \
# 0      1           Oslo       Norway             6480               6512
# 1      2         Bergen       Norway             7097               6876
# 2      3      Amsterdam  Netherlands             7540               5558
# 3      4     Copenhagen      Denmark             7490               7920
# 4      5      Stockholm       Sweden             6122               7692
# ..   ...            ...          ...              ...                ...
# 97    98           Riga       Latvia             4152               4584
# 98    99        Beijing        China             7610               2998
# 99   100  St Petersburg       Russia             4588               2908
# 100  101        Calgary       Canada             6675               4052
# 101  102       Edmonton       Canada             5801               4499
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# ...

# %%
# @title Verificamos si hay datos nulos
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Eliminamos las columnas _String_ para poder realizar el analisis de los datos

# %%
# @title Excluimos a la columna Id
df_sin_string = df.drop(['Id'], axis=1)

# %%
# @title Excluimos a la columna Country
df_sin_string1 = df.drop (['Id','City','Country'], axis=1)

# %% [markdown]
# #Medidas de tendencia central:

# %%
# @title Media
#sin string 1 es sin ningun str

promedios = df_sin_string1.mean()

# Crear el gráfico de barras verticales
plt.figure(figsize=(10, 6))
promedios.plot(kind='bar', color='skyblue')
plt.xlabel('Variables')
plt.ylabel('Promedio')
plt.title('Promedio de Variables')
plt.grid(axis='y')  # Agregar líneas de cuadrícula solo en el eje y
plt.show()

# %%
# @title Media Edmonton vs
# Filtrar el DataFrame para incluir solo las ciudades mencionadas
ciudades_seleccionadas = ['Edmonton','London', 'Paris',  'Calgary', 'St Petersburg', 'Copenhagen', 'Amsterdam', 'Oslo']
promedio_ciudades_seleccionadas = promedio_por_ciudad.loc[ciudades_seleccionadas]

# Crear el gráfico de barras apiladas
plt.figure(figsize=(12, 8))
ax = promedio_ciudades_seleccionadas.plot(kind='bar', stacked=True, colormap='coolwarm', alpha=0.8)

# Añadir etiquetas y título
plt.xlabel('Ciudades')
plt.ylabel('Promedio')
plt.title('Promedio de Variables por Ciudad')

# Mostrar el gráfico
plt.xticks(rotation=45)
plt.tight_layout()

# Añadir leyenda fuera del área de trazado principal
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
# @title Mediana
mediana = df_sin_string1.median()
mediana
# Out:
# Smart_Mobility                       5651.5
# Smart_Environment                    6495.0
# Smart_Government                     5911.0
# Smart_Economy                        6432.5
# Smart_People                         5747.5
# Smart_Living                         6485.0
# SmartCity_Index                      6261.5
# SmartCity_Index_relative_Edmonton    -210.5
# dtype: float64

# %%
# Create a sample dataframe similar to the one described
data = {
    'Category': ['Smart_Mobility', 'Smart_Environment', 'Smart_Government', 'Smart_Economy', 'Smart_People', 'Smart_Living', 'SmartCity_Index', 'SmartCity_Index_relative_Edmonton'],
    'Median': [5651.5, 6495.0, 5911.0, 6432.5, 5747.5, 6485.0, 6261.5, -210.5]
}

df_median = pd.DataFrame(data)

# Plot the data
plt.figure(figsize=(10, 6))
plt.bar(df_median['Category'], df_median['Median'], color='skyblue')
plt.xlabel('Category')
plt.ylabel('Median Value')
plt.title('Median Values for Different Smart City Categories')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %%
# @title Mediana Edmonton vs

 #Calcular la mediana por ciudad, ignorando las columnas no numéricas
mediana_por_ciudad = df_sin_string.groupby('City').median(numeric_only=True)

# Filtrar el DataFrame para incluir solo las ciudades seleccionadas
ciudades_seleccionadas = ['Edmonton','London', 'Paris',  'Calgary', 'St Petersburg', 'Copenhagen', 'Amsterdam', 'Oslo']
mediana_ciudades_seleccionadas = mediana_por_ciudad.loc[ciudades_seleccionadas]

# Crear el gráfico de barras apiladas
plt.figure(figsize=(12, 8))
mediana_ciudades_seleccionadas.plot(kind='bar', stacked=True, colormap='summer')

# Añadir etiquetas y título
plt.xlabel('Ciudades')
plt.ylabel('Mediana')
plt.title('Mediana de Variables por Ciudad')

# Mostrar el gráfico
plt.xticks(rotation=45)
plt.tight_layout()

# Obtener el objeto de ejes
ax = plt.gca()

# Añadir leyenda fuera del área de trazado principal
handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[::-1], labels[::-1], loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
# @title Moda
moda= df_sin_string.mode()
moda
# Out:
#                City Country  Smart_Mobility   Smart_Environment  \
# 0           Aalborg   Italy           5512.0             5224.0
# 1            Aarhus     NaN           7490.0             7090.0
# 2         Abu Dhabi     NaN              NaN             7102.0
# 3          Adelaide     NaN              NaN             8312.0
# 4         Amsterdam     NaN              NaN                NaN
# ..              ...     ...              ...                ...
# 97           Verona     NaN              NaN                NaN
# 98           Vienna     NaN              NaN                NaN
# 99         Västerås     NaN              NaN                NaN
# 100  Washington, DC     NaN              NaN                NaN
# 101          Zurich     NaN              NaN                NaN
#
#      Smart_Government   Smart_Economy   Smart_People  Smart_Living  \
# 0               5732.0          4905.0        4385.0        3950.0
# ...

# %%
from matplotlib import pyplot as plt
moda['Smart_Mobility '].plot(kind='hist', bins=20, title='Smart_Mobility ')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# @title Moda Edmonton vs
import seaborn as sns

# Define una paleta de colores personalizada
colors = ['#E6E6FA', '#FFB6C1', '#FF69B4', '#DA70D6', '#9370DB', '#8A2BE2', '#FFC0CB', '#DB7093']

# Calcular la moda por ciudad para las variables numéricas
moda_por_ciudad = df_sin_string.mode().groupby('City').agg(lambda x: x.iloc[0] if not x.empty else None)

# Filtrar el DataFrame para incluir solo las ciudades seleccionadas
ciudades_seleccionadas = ['London', 'Paris', 'Edmonton', 'Calgary', 'St Petersburg', 'Copenhagen', 'Amsterdam', 'Oslo']
moda_ciudades_seleccionadas = moda_por_ciudad.loc[ciudades_seleccionadas]

# Crear el gráfico de barras apiladas con la paleta de colores personalizada
plt.figure(figsize=(12, 8))
moda_ciudades_seleccionadas.plot(kind='bar', stacked=True, color=colors)

# Añadir etiquetas y título
plt.xlabel('Ciudades')
plt.ylabel('Moda')
plt.title('Moda de Variables por Ciudad')

# Mostrar el gráfico
plt.xticks(rotation=45)
plt.tight_layout()

# Añadir leyenda fuera del área de trazado principal
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1], loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
#@title Min
df_sin_string.min()
# Out:
# Smart_Mobility                       3175
# Smart_Environment                    1850
# Smart_Government                     2806
# Smart_Economy                        1490
# Smart_People                         2825
# Smart_Living                         1980
# SmartCity_Index                      4191
# SmartCity_Index_relative_Edmonton   -2281
# dtype: int64

# %%
# Datos del DataFrame
categories = ['Smart_Mobility', 'Smart_Environment', 'Smart_Government', 'Smart_Economy', 'Smart_People', 'Smart_Living', 'SmartCity_Index', 'SmartCity_Index_relative_Edmonton']
values = [3175, 1850, 2806, 1490, 2825, 1980, 4191, -2281]

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(categories, values, color='skyblue')

# Añadir título y etiquetas
plt.title('Valores de Smart City Index')
plt.xlabel('Valor')
plt.ylabel('Categoría')

# Mostrar el gráfico
plt.show()

# %%
# @title Mínimas Edmonton vs
import seaborn as sns

# Calcular la mínima por ciudad para las variables numéricas
min_por_ciudad = df_sin_string.groupby('City').min()

# Filtrar el DataFrame para incluir solo las ciudades seleccionadas
ciudades_seleccionadas = ['London', 'Paris', 'Edmonton', 'Calgary', 'St Petersburg', 'Copenhagen', 'Amsterdam', 'Oslo']
min_ciudades_seleccionadas = min_por_ciudad.loc[ciudades_seleccionadas]

# Crear el gráfico de barras apiladas con la paleta de colores personalizada
plt.figure(figsize=(12, 8))
min_ciudades_seleccionadas.plot(kind='bar', stacked=True, color=colors)

# Añadir etiquetas y título
plt.xlabel('Ciudades')
plt.ylabel('Mínima')
plt.title('Mínima de Variables por Ciudad')

# Mostrar el gráfico
plt.xticks(rotation=45)
plt.tight_layout()

# Añadir leyenda fuera del área de trazado principal
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1], loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
# @title Max
df_sin_string.max()
# Out:
# Smart_Mobility                        8110
# Smart_Environment                     8844
# Smart_Government                      8726
# Smart_Economy                         9225
# Smart_People                          9695
# Smart_Living                         10000
# SmartCity_Index                       7353
# SmartCity_Index_relative_Edmonton      880
# dtype: int64

# %%
# Datos del DataFrame
categories = ['Smart_Mobility', 'Smart_Environment', 'Smart_Government', 'Smart_Economy', 'Smart_People', 'Smart_Living', 'SmartCity_Index', 'SmartCity_Index_relative_Edmonton']
values = [8110, 8844, 8726, 9225, 9695, 10000, 7353, 880]

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(categories, values, color='lightgreen')

# Añadir título y etiquetas
plt.title('Valores de Smart City Index')
plt.xlabel('Valor')
plt.ylabel('Categoría')

# Mostrar el gráfico
plt.show()

# %%
# @title Máximas Edmonton vs
import seaborn as sns

# Calcular la máxima por ciudad para las variables numéricas
max_por_ciudad = df_sin_string.groupby('City').max()

# Filtrar el DataFrame para incluir solo las ciudades seleccionadas
ciudades_seleccionadas = ['London', 'Paris', 'Edmonton', 'Calgary', 'St Petersburg', 'Copenhagen', 'Amsterdam', 'Oslo']
max_ciudades_seleccionadas = max_por_ciudad.loc[ciudades_seleccionadas]

# Crear el gráfico de barras apiladas con la paleta de colores personalizada
plt.figure(figsize=(12, 8))
max_ciudades_seleccionadas.plot(kind='bar', stacked=True, color=colors)

# Añadir etiquetas y título
plt.xlabel('Ciudades')
plt.ylabel('Máxima')
plt.title('Máxima de Variables por Ciudad')

# Mostrar el gráfico
plt.xticks(rotation=45)
plt.tight_layout()

# Añadir leyenda fuera del área de trazado principal
handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles[::-1], labels[::-1], loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %% [markdown]
# # Medidas de dispersión

# %%
 # @title Rango
df_sin_string1.max() - df_sin_string1.min()
# Out:
# Smart_Mobility                       4935
# Smart_Environment                    6994
# Smart_Government                     5920
# Smart_Economy                        7735
# Smart_People                         6870
# Smart_Living                         8020
# SmartCity_Index                      3162
# SmartCity_Index_relative_Edmonton    3161
# dtype: int64

# %%
# Suponiendo que df_sin_string1 es tu DataFrame
# Calcula la diferencia entre el valor máximo y mínimo
rango = df_sin_string1.max() - df_sin_string1.min()

# Crea un gráfico de barras para visualizar el rango
plt.figure(figsize=(10, 6))
rango.plot(kind='bar')
plt.title('Rango de valores')
plt.xlabel('Columnas')
plt.ylabel('Rango')
plt.grid(True)
plt.show()

# %%
# @title Desviación Estandar
desviacion_estandar = df_sin_string1.std()
desviacion_estandar
# Out:
# Smart_Mobility                       1214.030137
# Smart_Environment                    1724.032171
# Smart_Government                     1153.375297
# Smart_Economy                        1801.555148
# Smart_People                         1449.096341
# Smart_Living                         2286.397477
# SmartCity_Index                       852.775180
# SmartCity_Index_relative_Edmonton     852.783238
# dtype: float64

# %%
# Desviación estándar de cada categoría
desviacion_estandar = df_sin_string1.std()

# Crear el gráfico de barras
plt.figure(figsize=(10, 6))
plt.barh(desviacion_estandar.index, desviacion_estandar, color='lightblue')

# Añadir título y etiquetas
plt.title('Desviación Estándar por Categoría')
plt.xlabel('Desviación Estándar')
plt.ylabel('Categoría')

# Mostrar el gráfico
plt.show()
